# %% [markdown]
# __Author: Samuel Estacio__

# %% [markdown]
# # __Book Rental Recommendation__
# ## Course-end Project 2
# ## __Description__
#
# Book Rent is the largest online and offline book rental chain in India. They provide books of various genres, such as thrillers, mysteries, romances, and science fiction. The company charges a fixed rental fee for a book per month. Lately, the company has been losing its user base. The main reason for this is that users are not able to choose the right books for themselves. The company wants to solve this problem and increase its revenue and profit.
#
# ## __Project Objective:__
#
# You, as an ML expert, should focus on improving the user experience by personalizing it to the user's needs. You have to model a recommendation engine so that users get recommendations for books based on the behavior of similar users. This will ensure that users are renting the books based on their tastes and traits.
#
# __Note:__ You have to perform user-based collaborative filtering and item-based collaborative filtering.
#
# ## __Dataset description:__
#
#  ###  __BX-Users:__ It contains the information of users.
#
#    __user_id__- These have been anonymized and mapped to integers
#
#    __Location__- Demographic data is provided
#
#    __Age__- Demographic data is provided
#
#         If available, otherwise, these fields contain __NULL-values__.
#
#
# ### __BX-Books:__
#
#    __isbn__ - Books are identified by their respective ISBNs. Invalid ISBNs have already been removed from the dataset.
#
#    __book_title__
#
#    __book_author__
#
#    __year_of_publication__
#
#    __publisher__
#
#
#
# ### __BX-Book-Ratings:__ Contains the book rating information.
#
#    __user_id__
#
#    __isbn__
#
#    __rating__ - Ratings (`Book-Rating`) are either explicit, expressed on a scale from 1–10 (higher values denoting higher appreciation), or implicit, expressed by 0.
#
#
#
# __Note:__ Download the “BX-Book-Ratings.csv”, “BX-Books.csv”, “BX-Users.csv”, and “Recommend.csv” using the link given in the Book Rental Recommendation project problem statement.

# %% [markdown]
# ## Read the books dataset and explore it

# %%
import pandas as pd
import numpy as np


df_books = pd.read_csv('BX-Books.csv',encoding='iso-8859-1')
df_users = pd.read_csv('BX-Users.csv',encoding='iso-8859-1')
df_br = pd.read_csv('BX-Book-Ratings.csv',encoding='iso-8859-1')
df_rec = pd.read_csv('Recommend.csv')
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\2003930415.py:5: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_books = pd.read_csv('BX-Books.csv',encoding='iso-8859-1')
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\2003930415.py:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_users = pd.read_csv('BX-Users.csv',encoding='iso-8859-1')

# %%
df_books.head()
# Out:
#         isbn                                         book_title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             book_author year_of_publication                   publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271379 entries, 0 to 271378
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   isbn                 271379 non-null  object
#  1   book_title           271379 non-null  object
#  2   book_author          271378 non-null  object
#  3   year_of_publication  271379 non-null  object
#  4   publisher            271377 non-null  object
# dtypes: object(5)
# memory usage: 10.4+ MB

# %%
df_books.isnull().sum(axis=0)
# Out:
# isbn                   0
# book_title             0
# book_author            1
# year_of_publication    0
# publisher              2
# dtype: int64

# %%
df_books[df_books.duplicated()]
# Out:
# Empty DataFrame
# Columns: [isbn, book_title, book_author, year_of_publication, publisher]
# Index: []

# %%
df_books[df_books.isna().any(axis=1)]
# Out:
#               isbn                                         book_title  \
# 128896  193169656X                                        Tyrant Moon
# 129043  1931696993                                    Finders Keepers
# 187700  9627982032  The Credit Suisse Guide to Managing Your Perso...
#
#             book_author year_of_publication                       publisher
# 128896  Elaine Corvidae                2002                             NaN
# 129043  Linnea Sinclair                2001                             NaN
# 187700              NaN                1995  Edinburgh Financial Publishing

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> Only three books out of 270K+ books have some missing info. No need to omit these books, but data should be cleansed properly if this was a real project.
# </div>

# %% [markdown]
# ## Clean up NaN values

# %%
df_books.isnull().sum(axis=0)
# Out:
# isbn                   0
# book_title             0
# book_author            1
# year_of_publication    0
# publisher              2
# dtype: int64

# %%
df_br.isnull().sum(axis=0)
# Out:
# user_id    0
# isbn       0
# rating     0
# dtype: int64

# %%
df_users.isnull().sum(axis=0)
# Out:
# user_id          0
# Location         1
# Age         110763
# dtype: int64

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278859 entries, 0 to 278858
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   278859 non-null  object
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 6.4+ MB

# %%
df_users[df_users.isna().any(axis=1)]
# Out:
#        user_id                            Location  Age
# 0            1                  nyc, new york, usa  NaN
# 2            3     moscow, yukon territory, russia  NaN
# 4            5  farnborough, hants, united kingdom  NaN
# 6            7                 washington, dc, usa  NaN
# 7            8            timmins, ontario, canada  NaN
# ...        ...                                 ...  ...
# 278850  278850          sergnano, lombardia, italy  NaN
# 278854  278854               portland, oregon, usa  NaN
# 278856  278856           brampton, ontario, canada  NaN
# 278857  278857           knoxville, tennessee, usa  NaN
# 278858  278858                dublin, n/a, ireland  NaN
#
# [110763 rows x 3 columns]

# %%
non_numeric_values = df_users[df_users['user_id'].apply(lambda x: not str(x).isnumeric())]
non_numeric_values
# Out:
#                 user_id Location  Age
# 275081  , milan, italy"      NaN  NaN

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> Lots of missing ages, but this could be due to family accounts, children or group accounts. Until we can figure that out, we will omit these users. Only 1 location null, which would have been able to work, but the user id is all messed up. This could be an issue with the CSV transformation, so we'll omit this one row as well.
# </div>

# %%
df_users = df_users.dropna()
df_users.isnull().sum(axis=0)
# Out:
# user_id     0
# Location    0
# Age         0
# dtype: int64

# %%
df_users.head()
# Out:
#    user_id                        Location   Age
# 1        2       stockton, california, usa  18.0
# 3        4       porto, v.n.gaia, portugal  17.0
# 5        6   santa monica, california, usa  61.0
# 9       10      albacete, wisconsin, spain  26.0
# 10      11  melbourne, victoria, australia  14.0

# %% [markdown]
# ## Read the data where ratings are given by users

# %%
df_br.head()
# Out:
#    user_id        isbn  rating
# 0   276725  034545104X       0
# 1   276726   155061224       5
# 2   276727   446520802       0
# 3   276729  052165615X       3
# 4   276729   521795028       6

# %%
df_br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1048575 non-null  int64
#  1   isbn     1048575 non-null  object
#  2   rating   1048575 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
df_br.isnull().sum(axis=0)
# Out:
# user_id    0
# isbn       0
# rating     0
# dtype: int64

# %%
df_br[df_br.duplicated()]
# Out:
#          user_id      isbn  rating
# 11338        709  9.78E+12       9
# 21604       4334  6.31E+11       0
# 28622       6575  6.31E+11       0
# 58876      11676  9.78E+12       9
# 58877      11676  9.78E+12       9
# ...          ...       ...     ...
# 1047765   250634  9.78E+12       0
# 1047766   250634  9.78E+12      10
# 1047767   250634  9.78E+12      10
# 1047768   250634  9.78E+12      10
# 1047769   250634  9.78E+12       0
#
# [146 rows x 3 columns]

# %% [markdown]
# ## Take a quick look at the number of unique users and books

# %%
unique_users = df_br['user_id'].nunique()
unique_books = df_br['isbn'].nunique()

print(f"Unique Users: {unique_users}")
print(f"Unique Books: {unique_books}")
# Out:
# Unique Users: 95513
# Unique Books: 322102

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> Let's look at all the other data sets and do some prep work too if needed.
# </div>

# %%
df_books.head()
# Out:
#         isbn                                         book_title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             book_author year_of_publication                   publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
df_users.head()
# Out:
#    user_id                        Location   Age
# 1        2       stockton, california, usa  18.0
# 3        4       porto, v.n.gaia, portugal  17.0
# 5        6   santa monica, california, usa  61.0
# 9       10      albacete, wisconsin, spain  26.0
# 10      11  melbourne, victoria, australia  14.0

# %%
df_br.head()
# Out:
#    user_id        isbn  rating
# 0   276725  034545104X       0
# 1   276726   155061224       5
# 2   276727   446520802       0
# 3   276729  052165615X       3
# 4   276729   521795028       6

# %%
df_rec.head()
# Out:
#    196  242  3  881250949
# 0  186  302  3  891717742
# 1   22  377  1  878887116
# 2  244   51  2  880606923
# 3  166  346  1  886397596
# 4  298  474  4  884182806

# %% [markdown]
# ## Convert ISBN variables to numeric numbers in the correct order

# %%
df_books = df_books.sort_values(by='book_title')
df_books = df_books.reset_index(drop=True)
df_books['bookid'] = df_books.index
df_books['bookid'] = df_books['bookid'].astype('int32')
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271379 entries, 0 to 271378
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   isbn                 271379 non-null  object
#  1   book_title           271379 non-null  object
#  2   book_author          271378 non-null  object
#  3   year_of_publication  271379 non-null  object
#  4   publisher            271377 non-null  object
#  5   bookid               271379 non-null  int32
# dtypes: int32(1), object(5)
# memory usage: 11.4+ MB

# %% [markdown]
# ## Convert the user_id variable to numeric numbers in the correct order

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> This request may not be necessary since user_id is already numeric.
# </div>

# %%
df_users['user_id'] = df_users['user_id'].astype('int32')
df_users['Age'] = df_users['Age'].astype('int16')
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168096 entries, 1 to 278855
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   168096 non-null  int32
#  1   Location  168096 non-null  object
#  2   Age       168096 non-null  int16
# dtypes: int16(1), int32(1), object(1)
# memory usage: 3.5+ MB

# %%
df_br['user_id'] = df_br['user_id'].astype('int32')
df_br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1048575 non-null  int32
#  1   isbn     1048575 non-null  object
#  2   rating   1048575 non-null  int64
# dtypes: int32(1), int64(1), object(1)
# memory usage: 20.0+ MB

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> We'll combine the books and book ratings dataframes to make a new dataframe with the book titles.
# </div>

# %%
df_combined = pd.merge(df_books,df_br,on='isbn')
df_combined = pd.merge(df_combined,df_users,on='user_id')
df_combined = df_combined[['book_title','user_id','rating']]

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 685498 entries, 0 to 685497
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   book_title  685498 non-null  object
#  1   user_id     685498 non-null  int32
#  2   rating      685498 non-null  int64
# dtypes: int32(1), int64(1), object(1)
# memory usage: 18.3+ MB

# %%
df_combined.head()
# Out:
#                                           book_title  user_id  rating
# 0   A Light in the Storm: The Civil War Diary of ...    55927       0
# 1  A Break with Charity: A Story about the Salem ...    55927       7
# 2  A Coal Miner's Bride: The Diary of Anetka Kami...    55927       0
# 3                            A Long Fatal Love Chase    55927       8
# 4       A Ride into Morning: The Story of Tempe Wick    55927       7

# %% [markdown]
# ## Convert both user_id and ISBN to the ordered list, i.e., from 0...n-1

# %%
df_combined = df_combined.sort_values(by=['book_title','user_id'], ascending=[True,True])
df_combined.head()
# Out:
#                                               book_title  user_id  rating
# 0       A Light in the Storm: The Civil War Diary of ...    55927       0
# 187                                Always Have Popsicles   172742       0
# 1872                Apple Magic (The Collector's series)   198711       0
# 8328                                        Dark Justice    98391      10
# 14107                                           Deceived   170595       0

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> For each book we can calculate the popularity (count of all ratings explicit and implicit), and the average rating (when the rating isn't 0).
# </div>

# %%
df_pop = df_combined.groupby('book_title').size().reset_index(name='pop')
df_pop.describe()
# Out:
#                  pop
# count  195346.000000
# mean        3.509148
# std        12.140860
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max      1931.000000

# %%
pop_filter = df_pop[df_pop['pop']>20] 
pop_filter
# Out:
#                                                book_title  pop
# 60                                           'Salem's Lot   34
# 100                                                09-Nov   24
# 169                                        10 Lb. Penalty   39
# 358                                        101 Dalmatians   33
# 563                       14,000 Things to Be Happy About   21
# ...                                                   ...  ...
# 195017                                               Zoya   68
# 195172                                \O\" Is for Outlaw"  150
# 195186  \Surely You're Joking, Mr. Feynman!\": Adventu...   36
# 195252                                                  e   30
# 195295                                           stardust   36
#
# [4459 rows x 2 columns]

# %%
rating_filter = df_combined[df_combined['rating']!=0] 
df_avgrating = rating_filter.groupby('book_title')['rating'].mean().reset_index()
df_avgrating.head()
# Out:
#                                           book_title     rating
# 0                                       Dark Justice  10.000000
# 1   Earth Prayers From around the World: 365 Pray...   8.333333
# 2   Final Fantasy Anthology: Official Strategy Gu...  10.000000
# 3   Flight of Fancy: American Heiresses (Zebra Ba...   8.000000
# 4   Garfield Bigger and Better (Garfield (Numbere...   7.000000

# %%
df_filtered = df_combined[df_combined['book_title'].isin(pop_filter['book_title'])]
df_filtered = df_filtered[df_filtered['rating']!=0] 
df_filtered = df_filtered.sort_values(by=['book_title','user_id'], ascending=[True,True])
df_filtered = df_filtered.reset_index(drop=True)
df_filtered
# Out:
#          book_title  user_id  rating
# 0      'Salem's Lot    33283      10
# 1      'Salem's Lot    56044       8
# 2      'Salem's Lot    60263      10
# 3      'Salem's Lot    70065       5
# 4      'Salem's Lot    71712       5
# ...             ...      ...     ...
# 88481      stardust   215929       8
# 88482      stardust   218552       5
# 88483      stardust   234359       7
# 88484      stardust   236754      10
# 88485      stardust   245295      10
#
# [88486 rows x 3 columns]

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> We used book popularity to bring down the number of books we are looking at to books that were read/related to 50 or more users as our threshold arbitrarily chosen as it was above the 75%ile. From there we added another filter that also pulled out 0/implicit ratings or books that were never rated.
# </div>

# %% [markdown]
# ## Re-index the columns to build a matrix

# %%
df_pcmat = df_filtered.pivot_table(index=['user_id'],columns=['book_title'],values='rating')
df_pcmat
# Out:
# book_title  'Salem's Lot  09-Nov  10 Lb. Penalty  101 Dalmatians  \
# user_id
# 19                   NaN     NaN             NaN             NaN
# 42                   NaN     NaN             NaN             NaN
# 44                   NaN     NaN             NaN             NaN
# 51                   NaN     NaN             NaN             NaN
# 56                   NaN     NaN             NaN             NaN
# ...                  ...     ...             ...             ...
# 278843               NaN     NaN             NaN             NaN
# 278844               NaN     NaN             NaN             NaN
# 278846               NaN     NaN             NaN             NaN
# 278849               NaN     NaN             NaN             NaN
# 278851               NaN     NaN             NaN             NaN
#
# book_title  14,000 Things to Be Happy About  16 Lighthouse Road  1984  \
# user_id
# 19                                      NaN                 NaN   NaN
# 42                                      NaN                 NaN   NaN
# 44                                      NaN                 NaN   NaN
# 51                                      NaN                 NaN   NaN
# 56                                      NaN                 NaN   NaN
# ...                                     ...                 ...   ...
# 278843                                  NaN                 NaN   NaN
# 278844                                  NaN                 NaN   NaN
# 278846                                  NaN                 NaN   NaN
# 278849                                  NaN                 NaN   NaN
# 278851                                  5.0                 NaN   NaN
#
# book_title  1st to Die: A Novel  2010: Odyssey Two  204 Rosewood Lane  ...  \
# user_id                                                                ...
# 19                          NaN                NaN                NaN  ...
# 42                          NaN                NaN                NaN  ...
# 44                          NaN                NaN                NaN  ...
# 51                          NaN                NaN                NaN  ...
# 56                          NaN                NaN                NaN  ...
# ...                         ...                ...                ...  ...
# 278843                      NaN                NaN                NaN  ...
# 278844                      NaN                NaN                NaN  ...
# 278846                      NaN                NaN                NaN  ...
# 278849                      NaN                NaN                NaN  ...
# 278851                      NaN                NaN                NaN  ...
#
# book_title  Yukon Ho!  Zen and the Art of Motorcycle Maintenance  \
# user_id
# 19                NaN                                        NaN
# 42                NaN                                        NaN
# 44                NaN                                        NaN
# 51                NaN                                        NaN
# 56                NaN                                        NaN
# ...               ...                                        ...
# 278843            NaN                                        NaN
# 278844            NaN                                        NaN
# 278846            NaN                                        NaN
# 278849            NaN                                        NaN
# 278851            NaN                                        NaN
#
# book_title  Zen and the Art of Motorcycle Maintenance: An Inquiry into Values  \
# user_id
# 19                                                        NaN
# 42                                                        NaN
# 44                                                        NaN
# 51                                                        NaN
# 56                                                        NaN
# ...                                                       ...
# 278843                                                    NaN
# 278844                                                    NaN
# 278846                                                    NaN
# 278849                                                    NaN
# 278851                                                    NaN
#
# book_title  Zlata's Diary: A Child's Life in Sarajevo  \
# user_id
# 19                                                NaN
# 42                                                NaN
# 44                                                NaN
# 51                                                NaN
# 56                                                NaN
# ...                                               ...
# 278843                                            NaN
# 278844                                            NaN
# 278846                                            NaN
# 278849                                            NaN
# 278851                                            NaN
#
# book_title  Zodiac: The Eco-Thriller  Zoya  \O\" Is for Outlaw"  \
# user_id
# 19                               NaN   NaN                  NaN
# 42                               NaN   NaN                  NaN
# 44                               NaN   NaN                  NaN
# 51                               NaN   NaN                  NaN
# 56                               NaN   NaN                  NaN
# ...                              ...   ...                  ...
# 278843                           NaN   NaN                  NaN
# 278844                           NaN   NaN                  NaN
# 278846                           NaN   NaN                  NaN
# 278849                           NaN   NaN                  NaN
# 278851                           NaN   NaN                  NaN
#
# book_title  \Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"  \
# user_id
# 19                                                        NaN
# 42                                                        NaN
# 44                                                        NaN
# 51                                                        NaN
# 56                                                        NaN
# ...                                                       ...
# 278843                                                    NaN
# 278844                                                    NaN
# 278846                                                    NaN
# 278849                                                    NaN
# 278851                                                    NaN
#
# book_title   e  stardust
# user_id
# 19         NaN       NaN
# 42         NaN       NaN
# 44         NaN       NaN
# 51         NaN       NaN
# 56         NaN       NaN
# ...         ..       ...
# 278843     NaN       NaN
# 278844     NaN       NaN
# 278846     NaN       NaN
# 278849     NaN       NaN
# 278851     NaN       NaN
#
# [21304 rows x 4459 columns]

# %%
corrMatrix = df_pcmat.corr(method='pearson',min_periods=30)
corrMatrix.head()
# Out:
# book_title                       'Salem's Lot  09-Nov  10 Lb. Penalty  \
# book_title
# 'Salem's Lot                              NaN     NaN             NaN
# 09-Nov                                    NaN     NaN             NaN
# 10 Lb. Penalty                            NaN     NaN             NaN
# 101 Dalmatians                            NaN     NaN             NaN
# 14,000 Things to Be Happy About           NaN     NaN             NaN
#
# book_title                       101 Dalmatians  \
# book_title
# 'Salem's Lot                                NaN
# 09-Nov                                      NaN
# 10 Lb. Penalty                              NaN
# 101 Dalmatians                              NaN
# 14,000 Things to Be Happy About             NaN
#
# book_title                       14,000 Things to Be Happy About  \
# book_title
# 'Salem's Lot                                                 NaN
# 09-Nov                                                       NaN
# 10 Lb. Penalty                                               NaN
# 101 Dalmatians                                               NaN
# 14,000 Things to Be Happy About                              NaN
#
# book_title                       16 Lighthouse Road  1984  \
# book_title
# 'Salem's Lot                                    NaN   NaN
# 09-Nov                                          NaN   NaN
# 10 Lb. Penalty                                  NaN   NaN
# 101 Dalmatians                                  NaN   NaN
# 14,000 Things to Be Happy About                 NaN   NaN
#
# book_title                       1st to Die: A Novel  2010: Odyssey Two  \
# book_title
# 'Salem's Lot                                     NaN                NaN
# 09-Nov                                           NaN                NaN
# 10 Lb. Penalty                                   NaN                NaN
# 101 Dalmatians                                   NaN                NaN
# 14,000 Things to Be Happy About                  NaN                NaN
#
# book_title                       204 Rosewood Lane  ...  Yukon Ho!  \
# book_title                                          ...
# 'Salem's Lot                                   NaN  ...        NaN
# 09-Nov                                         NaN  ...        NaN
# 10 Lb. Penalty                                 NaN  ...        NaN
# 101 Dalmatians                                 NaN  ...        NaN
# 14,000 Things to Be Happy About                NaN  ...        NaN
#
# book_title                       Zen and the Art of Motorcycle Maintenance  \
# book_title
# 'Salem's Lot                                                           NaN
# 09-Nov                                                                 NaN
# 10 Lb. Penalty                                                         NaN
# 101 Dalmatians                                                         NaN
# 14,000 Things to Be Happy About                                        NaN
#
# book_title                       Zen and the Art of Motorcycle Maintenance: An Inquiry into Values  \
# book_title
# 'Salem's Lot                                                                   NaN
# 09-Nov                                                                         NaN
# 10 Lb. Penalty                                                                 NaN
# 101 Dalmatians                                                                 NaN
# 14,000 Things to Be Happy About                                                NaN
#
# book_title                       Zlata's Diary: A Child's Life in Sarajevo  \
# book_title
# 'Salem's Lot                                                           NaN
# 09-Nov                                                                 NaN
# 10 Lb. Penalty                                                         NaN
# 101 Dalmatians                                                         NaN
# 14,000 Things to Be Happy About                                        NaN
#
# book_title                       Zodiac: The Eco-Thriller  Zoya  \
# book_title
# 'Salem's Lot                                          NaN   NaN
# 09-Nov                                                NaN   NaN
# 10 Lb. Penalty                                        NaN   NaN
# 101 Dalmatians                                        NaN   NaN
# 14,000 Things to Be Happy About                       NaN   NaN
#
# book_title                       \O\" Is for Outlaw"  \
# book_title
# 'Salem's Lot                                     NaN
# 09-Nov                                           NaN
# 10 Lb. Penalty                                   NaN
# 101 Dalmatians                                   NaN
# 14,000 Things to Be Happy About                  NaN
#
# book_title                       \Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"  \
# book_title
# 'Salem's Lot                                                                   NaN
# 09-Nov                                                                         NaN
# 10 Lb. Penalty                                                                 NaN
# 101 Dalmatians                                                                 NaN
# 14,000 Things to Be Happy About                                                NaN
#
# book_title                        e  stardust
# book_title
# 'Salem's Lot                    NaN       NaN
# 09-Nov                          NaN       NaN
# 10 Lb. Penalty                  NaN       NaN
# 101 Dalmatians                  NaN       NaN
# 14,000 Things to Be Happy About NaN       NaN
#
# [5 rows x 4459 columns]

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> We chose 30 as the minimum periods arbitrarily as well, but we could perform some statistical analysis to test what would be an acceptable threshold. The lower, the more costly/expensive in processing.
# </div>

# %% [markdown]
# ## Split your data into two sets (training and testing)

# %%
df_pcmat[df_pcmat.count(axis=1) >= 7]
# Out:
# book_title  'Salem's Lot  09-Nov  10 Lb. Penalty  101 Dalmatians  \
# user_id
# 254                  NaN     NaN             NaN             NaN
# 388                  NaN     NaN             NaN             NaN
# 503                  NaN     NaN             NaN             NaN
# 638                  NaN     NaN             NaN             NaN
# 805                  NaN     NaN             NaN             NaN
# ...                  ...     ...             ...             ...
# 278221               NaN     NaN             NaN             NaN
# 278356               NaN     NaN             NaN             NaN
# 278390               NaN     NaN             NaN             NaN
# 278554               NaN     NaN             NaN             NaN
# 278843               NaN     NaN             NaN             NaN
#
# book_title  14,000 Things to Be Happy About  16 Lighthouse Road  1984  \
# user_id
# 254                                     NaN                 NaN   9.0
# 388                                     NaN                 NaN   NaN
# 503                                     NaN                 NaN   NaN
# 638                                     NaN                 NaN   NaN
# 805                                     NaN                 NaN   NaN
# ...                                     ...                 ...   ...
# 278221                                  NaN                 NaN   NaN
# 278356                                  NaN                 NaN   NaN
# 278390                                  NaN                 NaN   NaN
# 278554                                  NaN                 NaN   NaN
# 278843                                  NaN                 NaN   NaN
#
# book_title  1st to Die: A Novel  2010: Odyssey Two  204 Rosewood Lane  ...  \
# user_id                                                                ...
# 254                         NaN                NaN                NaN  ...
# 388                         NaN                NaN                NaN  ...
# 503                         NaN                NaN                NaN  ...
# 638                         NaN                NaN                NaN  ...
# 805                         NaN                NaN                NaN  ...
# ...                         ...                ...                ...  ...
# 278221                      NaN                NaN                NaN  ...
# 278356                      NaN                NaN                NaN  ...
# 278390                      NaN                NaN                NaN  ...
# 278554                      NaN                NaN                NaN  ...
# 278843                      NaN                NaN                NaN  ...
#
# book_title  Yukon Ho!  Zen and the Art of Motorcycle Maintenance  \
# user_id
# 254               NaN                                        NaN
# 388               NaN                                        NaN
# 503               NaN                                        NaN
# 638               NaN                                        NaN
# 805               NaN                                        NaN
# ...               ...                                        ...
# 278221            NaN                                        NaN
# 278356            NaN                                        NaN
# 278390            NaN                                        NaN
# 278554            NaN                                        NaN
# 278843            NaN                                        NaN
#
# book_title  Zen and the Art of Motorcycle Maintenance: An Inquiry into Values  \
# user_id
# 254                                                       NaN
# 388                                                       NaN
# 503                                                       NaN
# 638                                                       NaN
# 805                                                       NaN
# ...                                                       ...
# 278221                                                    NaN
# 278356                                                    NaN
# 278390                                                    NaN
# 278554                                                    NaN
# 278843                                                    NaN
#
# book_title  Zlata's Diary: A Child's Life in Sarajevo  \
# user_id
# 254                                               NaN
# 388                                               NaN
# 503                                               NaN
# 638                                               NaN
# 805                                               NaN
# ...                                               ...
# 278221                                            NaN
# 278356                                            NaN
# 278390                                            NaN
# 278554                                            NaN
# 278843                                            NaN
#
# book_title  Zodiac: The Eco-Thriller  Zoya  \O\" Is for Outlaw"  \
# user_id
# 254                              NaN   NaN                  NaN
# 388                              NaN   NaN                  NaN
# 503                              NaN   NaN                  NaN
# 638                              NaN   NaN                  NaN
# 805                              NaN   NaN                  NaN
# ...                              ...   ...                  ...
# 278221                           NaN   NaN                  NaN
# 278356                           NaN   NaN                  NaN
# 278390                           NaN   NaN                  NaN
# 278554                           NaN   NaN                  NaN
# 278843                           NaN   NaN                  NaN
#
# book_title  \Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"  \
# user_id
# 254                                                       NaN
# 388                                                       NaN
# 503                                                       NaN
# 638                                                       NaN
# 805                                                       NaN
# ...                                                       ...
# 278221                                                    NaN
# 278356                                                    NaN
# 278390                                                    NaN
# 278554                                                    NaN
# 278843                                                    NaN
#
# book_title   e  stardust
# user_id
# 254        NaN       NaN
# 388        NaN       NaN
# 503        NaN       NaN
# 638        NaN       NaN
# 805        NaN       NaN
# ...         ..       ...
# 278221     NaN       NaN
# 278356     NaN       NaN
# 278390     NaN       NaN
# 278554     NaN       NaN
# 278843     NaN       NaN
#
# [2727 rows x 4459 columns]

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> These 2290 users have provided input on at least 7 books which would be good examples to test our model against. We will look at the first user/row here user_id=254 and make predictions on related books using the correlation matrix.
# </div>

# %%
friend_ratings = df_pcmat.loc[254].dropna()
friend_ratings
# Out:
# book_title
# 1984                                                                         9.0
# American Gods                                                               10.0
# American Gods: A Novel                                                       9.0
# Animal Farm                                                                  8.0
# Complete Chronicles of Narnia                                                5.0
# Familiar Lullaby (Fear Familiar) (Harlequin Intrigue, No 614)                5.0
# Harry Potter and the Chamber of Secrets (Book 2)                             9.0
# Harry Potter and the Goblet of Fire (Book 4)                                 9.0
# Harry Potter and the Prisoner of Azkaban (Book 3)                            9.0
# Harry Potter and the Sorcerer's Stone (Book 1)                               9.0
# Making Minty Malone                                                          7.0
# Martian Chronicles                                                           8.5
# Neverwhere                                                                  10.0
# She's Come Undone (Oprah's Book Club)                                        7.0
# Smoke and Mirrors: Short Fictions and Illusions                              9.0
# Something Wicked This Way Comes                                              8.0
# Stardust                                                                     8.0
# The Bonesetter's Daughter                                                    9.0
# The Dark Half                                                                8.0
# The Fellowship of the Ring (The Lord of the Rings, Part 1)                   8.0
# The Golden Compass (His Dark Materials, Book 1)                              8.5
# The Hobbit: or There and Back Again                                          9.0
# The Lion, the Witch, and the Wardrobe (The Chronicles of Narnia, Book 2)     7.0
# The Secret Life of Bees                                                      9.0
# The Subtle Knife (His Dark Materials, Book 2)                                9.0
# Name: 254, dtype: float64

# %% [markdown]
# ## Make predictions based on user and item variables

# %%
simcandidates= pd.Series()
for i in range(0,len(friend_ratings.index)):
    print('Adding similars to ', friend_ratings.index[i])
    
    print('--------------------------------')
    sims = corrMatrix[friend_ratings.index[i]].dropna()
    sims = sims.map(lambda x: x*friend_ratings[i]) # Assigning lower weights to books with lower ratings.
    simcandidates  = simcandidates.append(sims)
    
    print('sorting')
    
    simcandidates.sort_values(inplace=True,ascending=False)
    
    print(simcandidates.head(10))
    print(" ")
    print(" ")
# Out:
# Adding similars to  1984
# --------------------------------
# sorting
# 1984    9.0
# dtype: float64
#
#
# Adding similars to  American Gods
# --------------------------------
# sorting
# American Gods    10.0
# 1984              9.0
# dtype: float64
#
#
# Adding similars to  American Gods: A Novel
# --------------------------------
# sorting
# American Gods    10.0
# 1984              9.0
# dtype: float64
#
#
# Adding similars to  Animal Farm
# --------------------------------
# sorting
# American Gods    10.0
# 1984              9.0
# Animal Farm       8.0
# dtype: float64
#
#
# Adding similars to  Complete Chronicles of Narnia
# --------------------------------
# sorting
# American Gods    10.0
# 1984              9.0
# Animal Farm       8.0
# dtype: float64
#
#
# Adding similars to  Familiar Lullaby (Fear Familiar) (Harlequin Intrigue, No 614)
# --------------------------------
# sorting
# American Gods    10.0
# 1984              9.0
# Animal Farm       8.0
# dtype: float64
#
#
# Adding similars to  Harry Potter and the Chamber of Secrets (Book 2)
# --------------------------------
# sorting
# American Gods                                                       10.000000
# 1984                                                                 9.000000
# Harry Potter and the Chamber of Secrets (Book 2)                     9.000000
# Animal Farm                                                          8.000000
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))     7.736446
# Harry Potter and the Sorcerer's Stone (Book 1)                       7.646853
# Harry Potter and the Prisoner of Azkaban (Book 3)                    6.361171
# Harry Potter and the Goblet of Fire (Book 4)                         6.025574
# Harry Potter and the Order of the Phoenix (Book 5)                   3.411608
# dtype: float64
#
#
# Adding similars to  Harry Potter and the Goblet of Fire (Book 4)
# --------------------------------
# sorting
# American Gods                                                       10.000000
# 1984                                                                 9.000000
# Harry Potter and the Chamber of Secrets (Book 2)                     9.000000
# Harry Potter and the Goblet of Fire (Book 4)                         9.000000
# Animal Farm                                                          8.000000
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))     7.736446
# Harry Potter and the Sorcerer's Stone (Book 1)                       7.646853
# Harry Potter and the Sorcerer's Stone (Book 1)                       7.618658
# Harry Potter and the Prisoner of Azkaban (Book 3)                    6.941900
# Harry Potter and the Prisoner of Azkaban (Book 3)                    6.361171
# dtype: float64
#
#
# Adding similars to  Harry Potter and the Prisoner of Azkaban (Book 3)
# --------------------------------
# sorting
# American Gods                                                       10.000000
# Harry Potter and the Chamber of Secrets (Book 2)                     9.000000
# Harry Potter and the Goblet of Fire (Book 4)                         9.000000
# 1984                                                                 9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)                    9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)                       8.111821
# Animal Farm                                                          8.000000
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))     7.736446
# Harry Potter and the Sorcerer's Stone (Book 1)                       7.646853
# Harry Potter and the Sorcerer's Stone (Book 1)                       7.618658
# dtype: float64
#
#
# Adding similars to  Harry Potter and the Sorcerer's Stone (Book 1)
# --------------------------------
# sorting
# American Gods                                         10.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)      9.000000
# Harry Potter and the Chamber of Secrets (Book 2)       9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)         9.000000
# 1984                                                   9.000000
# Harry Potter and the Goblet of Fire (Book 4)           9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)      8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)         8.111821
# Animal Farm                                            8.000000
# Harry Potter and the Order of the Phoenix (Book 5)     7.772023
# dtype: float64
#
#
# Adding similars to  Making Minty Malone
# --------------------------------
# sorting
# American Gods                                         10.000000
# Harry Potter and the Chamber of Secrets (Book 2)       9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)         9.000000
# 1984                                                   9.000000
# Harry Potter and the Goblet of Fire (Book 4)           9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)      9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)      8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)         8.111821
# Animal Farm                                            8.000000
# Harry Potter and the Order of the Phoenix (Book 5)     7.772023
# dtype: float64
#
#
# Adding similars to  Martian Chronicles
# --------------------------------
# sorting
# American Gods                                         10.000000
# Harry Potter and the Sorcerer's Stone (Book 1)         9.000000
# 1984                                                   9.000000
# Harry Potter and the Goblet of Fire (Book 4)           9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)      9.000000
# Harry Potter and the Chamber of Secrets (Book 2)       9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)      8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)         8.111821
# Animal Farm                                            8.000000
# Harry Potter and the Order of the Phoenix (Book 5)     7.772023
# dtype: float64
#
#
# Adding similars to  Neverwhere
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# 1984                                                  9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# Animal Farm                                           8.000000
# dtype: float64
#
#
# Adding similars to  She's Come Undone (Oprah's Book Club)
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# 1984                                                  9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# Animal Farm                                           8.000000
# dtype: float64
#
#
# Adding similars to  Smoke and Mirrors: Short Fictions and Illusions
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# 1984                                                  9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# Animal Farm                                           8.000000
# dtype: float64
#
#
# Adding similars to  Something Wicked This Way Comes
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# 1984                                                  9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# Animal Farm                                           8.000000
# dtype: float64
#
#
# Adding similars to  Stardust
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# 1984                                                  9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# Animal Farm                                           8.000000
# dtype: float64
#
#
# Adding similars to  The Bonesetter's Daughter
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# The Bonesetter's Daughter                             9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# 1984                                                  9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# dtype: float64
#
#
# Adding similars to  The Dark Half
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# The Bonesetter's Daughter                             9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# 1984                                                  9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# dtype: float64
#
#
# Adding similars to  The Fellowship of the Ring (The Lord of the Rings, Part 1)
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# The Bonesetter's Daughter                             9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# 1984                                                  9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# Harry Potter and the Prisoner of Azkaban (Book 3)     8.111821
# dtype: float64
#
#
# Adding similars to  The Golden Compass (His Dark Materials, Book 1)
# --------------------------------
# sorting
# American Gods                                        10.000000
# Neverwhere                                           10.000000
# Harry Potter and the Chamber of Secrets (Book 2)      9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)        9.000000
# The Bonesetter's Daughter                             9.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.000000
# Harry Potter and the Goblet of Fire (Book 4)          9.000000
# 1984                                                  9.000000
# The Golden Compass (His Dark Materials, Book 1)       8.500000
# Harry Potter and the Sorcerer's Stone (Book 1)        8.111821
# dtype: float64
#
#
# Adding similars to  The Hobbit: or There and Back Again
# --------------------------------
# sorting
# American Gods                                        10.0
# Neverwhere                                           10.0
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.0
# 1984                                                  9.0
# Harry Potter and the Goblet of Fire (Book 4)          9.0
# The Hobbit: or There and Back Again                   9.0
# The Bonesetter's Daughter                             9.0
# Harry Potter and the Sorcerer's Stone (Book 1)        9.0
# Harry Potter and the Chamber of Secrets (Book 2)      9.0
# The Golden Compass (His Dark Materials, Book 1)       8.5
# dtype: float64
#
#
# Adding similars to  The Lion, the Witch, and the Wardrobe (The Chronicles of Narnia, Book 2)
# --------------------------------
# sorting
# American Gods                                        10.0
# Neverwhere                                           10.0
# The Hobbit: or There and Back Again                   9.0
# Harry Potter and the Sorcerer's Stone (Book 1)        9.0
# The Bonesetter's Daughter                             9.0
# Harry Potter and the Chamber of Secrets (Book 2)      9.0
# Harry Potter and the Goblet of Fire (Book 4)          9.0
# 1984                                                  9.0
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.0
# The Golden Compass (His Dark Materials, Book 1)       8.5
# dtype: float64
#
#
# Adding similars to  The Secret Life of Bees
# --------------------------------
# sorting
# American Gods                                        10.0
# Neverwhere                                           10.0
# Harry Potter and the Goblet of Fire (Book 4)          9.0
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.0
# 1984                                                  9.0
# The Secret Life of Bees                               9.0
# Harry Potter and the Chamber of Secrets (Book 2)      9.0
# The Bonesetter's Daughter                             9.0
# Harry Potter and the Sorcerer's Stone (Book 1)        9.0
# The Hobbit: or There and Back Again                   9.0
# dtype: float64
#
#
# Adding similars to  The Subtle Knife (His Dark Materials, Book 2)
# --------------------------------
# sorting
# American Gods                                        10.0
# Neverwhere                                           10.0
# Harry Potter and the Chamber of Secrets (Book 2)      9.0
# The Hobbit: or There and Back Again                   9.0
# Harry Potter and the Sorcerer's Stone (Book 1)        9.0
# The Bonesetter's Daughter                             9.0
# The Subtle Knife (His Dark Materials, Book 2)         9.0
# The Secret Life of Bees                               9.0
# Harry Potter and the Goblet of Fire (Book 4)          9.0
# Harry Potter and the Prisoner of Azkaban (Book 3)     9.0
# dtype: float64
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   simcandidates= pd.Series()
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)
# C:\Users\samue\AppData\Local\Temp\ipykernel_24680\952331618.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simcandidates  = simcandidates.append(sims)

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> For each book rating, we provide a list of up to ten books that would be similar to the one this user read, as well as the potential rating. Sometimes the rating might be low, and we should be careful to recommend a lower scoring book. Below, is a summary averaging the predicted scores across all books.
# </div>

# %%
simcandidates = simcandidates.groupby(simcandidates.index).mean()
simcandidates.sort_values(inplace=True,ascending=False)
simcandidates
# Out:
# Neverwhere                                                                  10.000000
# American Gods                                                               10.000000
# The Secret Life of Bees                                                      9.000000
# The Hobbit: or There and Back Again                                          9.000000
# The Bonesetter's Daughter                                                    9.000000
# 1984                                                                         9.000000
# Harry Potter and the Sorcerer's Stone (Book 1)                               8.094333
# The Subtle Knife (His Dark Materials, Book 2)                                8.049340
# The Golden Compass (His Dark Materials, Book 1)                              8.008125
# The Dark Half                                                                8.000000
# The Fellowship of the Ring (The Lord of the Rings, Part 1)                   8.000000
# Animal Farm                                                                  8.000000
# Harry Potter and the Prisoner of Azkaban (Book 3)                            7.603723
# Harry Potter and the Goblet of Fire (Book 4)                                 7.396533
# Harry Potter and the Chamber of Secrets (Book 2)                             7.258399
# She's Come Undone (Oprah's Book Club)                                        7.000000
# The Lion, the Witch, and the Wardrobe (The Chronicles of Narnia, Book 2)     7.000000
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))             6.369908
# The Amber Spyglass (His Dark Materials, Book 3)                              6.087494
# Harry Potter and the Order of the Phoenix (Book 5)                           5.714342
# The Return of the King (The Lord of the Rings, Part 3)                       4.798394
# The Two Towers (The Lord of the Rings, Part 2)                               3.757577
# The Lovely Bones: A Novel                                                    2.112748
# dtype: float64

# %% [markdown]
# ## Use RMSE to evaluate the predictions

# %%
df_actual = friend_ratings.to_frame()
df_actual.reset_index(inplace=True)
df_actual.rename(columns={254:'actual'}, inplace=True)
df_actual
# Out:
#                                            book_title  actual
# 0                                                1984     9.0
# 1                                       American Gods    10.0
# 2                              American Gods: A Novel     9.0
# 3                                         Animal Farm     8.0
# 4                       Complete Chronicles of Narnia     5.0
# 5   Familiar Lullaby (Fear Familiar) (Harlequin In...     5.0
# 6    Harry Potter and the Chamber of Secrets (Book 2)     9.0
# 7        Harry Potter and the Goblet of Fire (Book 4)     9.0
# 8   Harry Potter and the Prisoner of Azkaban (Book 3)     9.0
# 9      Harry Potter and the Sorcerer's Stone (Book 1)     9.0
# 10                                Making Minty Malone     7.0
# 11                                 Martian Chronicles     8.5
# 12                                         Neverwhere    10.0
# 13              She's Come Undone (Oprah's Book Club)     7.0
# 14    Smoke and Mirrors: Short Fictions and Illusions     9.0
# 15                    Something Wicked This Way Comes     8.0
# 16                                           Stardust     8.0
# 17                          The Bonesetter's Daughter     9.0
# 18                                      The Dark Half     8.0
# 19  The Fellowship of the Ring (The Lord of the Ri...     8.0
# 20    The Golden Compass (His Dark Materials, Book 1)     8.5
# 21                The Hobbit: or There and Back Again     9.0
# 22  The Lion, the Witch, and the Wardrobe (The Chr...     7.0
# 23                            The Secret Life of Bees     9.0
# 24      The Subtle Knife (His Dark Materials, Book 2)     9.0

# %%
df_predicted = simcandidates.to_frame()
df_predicted.reset_index(inplace=True)
df_predicted.rename(columns={'index':'book_title',0:'predicted'}, inplace=True)
df_predicted
# Out:
#                                            book_title  predicted
# 0                                          Neverwhere  10.000000
# 1                                       American Gods  10.000000
# 2                             The Secret Life of Bees   9.000000
# 3                 The Hobbit: or There and Back Again   9.000000
# 4                           The Bonesetter's Daughter   9.000000
# 5                                                1984   9.000000
# 6      Harry Potter and the Sorcerer's Stone (Book 1)   8.094333
# 7       The Subtle Knife (His Dark Materials, Book 2)   8.049340
# 8     The Golden Compass (His Dark Materials, Book 1)   8.008125
# 9                                       The Dark Half   8.000000
# 10  The Fellowship of the Ring (The Lord of the Ri...   8.000000
# 11                                        Animal Farm   8.000000
# 12  Harry Potter and the Prisoner of Azkaban (Book 3)   7.603723
# 13       Harry Potter and the Goblet of Fire (Book 4)   7.396533
# 14   Harry Potter and the Chamber of Secrets (Book 2)   7.258399
# 15              She's Come Undone (Oprah's Book Club)   7.000000
# 16  The Lion, the Witch, and the Wardrobe (The Chr...   7.000000
# 17  Harry Potter and the Sorcerer's Stone (Harry P...   6.369908
# 18    The Amber Spyglass (His Dark Materials, Book 3)   6.087494
# 19  Harry Potter and the Order of the Phoenix (Boo...   5.714342
# 20  The Return of the King (The Lord of the Rings,...   4.798394
# 21     The Two Towers (The Lord of the Rings, Part 2)   3.757577
# 22                          The Lovely Bones: A Novel   2.112748

# %%
avp = pd.merge(df_actual, df_predicted, on='book_title', how='inner')
avp['se'] = (avp['actual']-avp['predicted'])**2
avp
# Out:
#                                            book_title  actual  predicted  \
# 0                                                1984     9.0   9.000000
# 1                                       American Gods    10.0  10.000000
# 2                                         Animal Farm     8.0   8.000000
# 3    Harry Potter and the Chamber of Secrets (Book 2)     9.0   7.258399
# 4        Harry Potter and the Goblet of Fire (Book 4)     9.0   7.396533
# 5   Harry Potter and the Prisoner of Azkaban (Book 3)     9.0   7.603723
# 6      Harry Potter and the Sorcerer's Stone (Book 1)     9.0   8.094333
# 7                                          Neverwhere    10.0  10.000000
# 8               She's Come Undone (Oprah's Book Club)     7.0   7.000000
# 9                           The Bonesetter's Daughter     9.0   9.000000
# 10                                      The Dark Half     8.0   8.000000
# 11  The Fellowship of the Ring (The Lord of the Ri...     8.0   8.000000
# 12    The Golden Compass (His Dark Materials, Book 1)     8.5   8.008125
# 13                The Hobbit: or There and Back Again     9.0   9.000000
# 14  The Lion, the Witch, and the Wardrobe (The Chr...     7.0   7.000000
# 15                            The Secret Life of Bees     9.0   9.000000
# 16      The Subtle Knife (His Dark Materials, Book 2)     9.0   8.049340
#
#           se
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   3.033172
# 4   2.571106
# 5   1.949590
# 6   0.820233
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.241941
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.903754

# %%
mse = avp['se'].mean()
rmse = np.sqrt(mse)
print("RMSE: ",rmse)
# Out:
# RMSE:  0.7483234643710263

# %% [markdown]
# <div class="note" style="background-color: #b7e1cd; padding: 10px;">
#     <strong>Note:</strong> Through iteratative testing, we found that the more books we included in the correlation matrix (when setting the pop_filter variable), the lower our RMSE, however including more books also proved to be more computationally expensive and took long to calculate, or broke the server due to lack of resources. Additionally, adjusting the min_periods hyperparameter led to varying RMSE results. With the demonstrated inputs the model is good at finding like-books, but not great at predicting ratings.
# </div>
